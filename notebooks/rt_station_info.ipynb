# %%
import sys
from utils.path import get_git_root
sys.path.insert(0, get_git_root().as_posix())

from utils.api_client import APIClient
from scripts.config import API_PUB_BASE_URL, RT_PACKAGE_PARAMS

client = APIClient(API_PUB_BASE_URL, RT_PACKAGE_PARAMS)
client.get_endpoints()
# Out:
# {'system regions': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_regions',
#  'system_information': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_information',
#  'station_information': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information',
#  'station_status': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status',
#  'system_pricing_plans': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_pricing_plans'}

# %%
station_endpoint = client.fetch_data("station_information")
station_endpoint["last_updated"]
# Out:
# 1781837404

# %%
station_info = station_endpoint["data"]["stations"]
station_info
# Out:
# [{'station_id': '7000',
#   'external_id': 'f8aa7900-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Fort York  Blvd / Capreol Ct',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.639832,
#   'lon': -79.395954,
#   'altitude': None,
#   'address': 'Fort York  Blvd / Capreol Ct',
#   'capacity': 47,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-643-9607',
#   'short_name': '647-643-9607',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7001',
#   'external_id': 'f8aaeb6e-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Wellesley Station Green P',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.66496415990742,
#   'lon': -79.38355031526893,
#   'altitude': None,
#   'address': 'Yonge / Wellesley',
#   'post_code': 'M4Y 1G7',
#   'capacity': 23,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'South', 'Church Wellesley / Yorkville'],
#   'obcn': '416-617-9576',
#   'short_name': '416-617-9576',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7002',
#   'external_id': 'f8aaef03-e9c7-11ef-984e-124c66246c7d',
#   'name': 'St. George St / Bloor St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.66713121831853,
#   'lon': -79.3995550638237,
#   'altitude': None,
#   'address': 'St. George St / Bloor St W',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9615',
#   'short_name': '647-643-9615',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7003',
#   'external_id': 'f8ab20ac-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Madison Ave / Bloor St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.66701830465472,
#   'lon': -79.4027958687172,
#   'altitude': None,
#   'address': 'Madison Ave / Bloor St W',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Bloor St W / Annex'],
#   'obcn': '647-631-4587',
#   'short_name': '647-631-4587',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7005',
#   'external_id': 'f8ab51f8-e9c7-11ef-984e-124c66246c7d',
#   'name': 'King St W / York St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6480008,
#   'lon': -79.383177,
#   'altitude': 0.0,
#   'address': 'King St W / York St',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-643-9693',
#   'short_name': '647-643-9693',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7006',
#   'external_id': 'f8ab54c0-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / College St (East Side)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.660439,
#   'lon': -79.385525,
#   'altitude': None,
#   'address': 'Bay St / College St (East Side)',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '416-569-2349',
#   'short_name': '416-569-2349',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7007',
#   'external_id': 'f8ab576d-e9c7-11ef-984e-124c66246c7d',
#   'name': 'College St / Huron St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.658148,
#   'lon': -79.398167,
#   'altitude': None,
#   'address': 'College St / Huron St',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-625-3582',
#   'short_name': '647-625-3582',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7008',
#   'external_id': 'f8ab5a3f-e9c7-11ef-984e-124c66246c7d',
#   'name': "Wellesley St W / Queen's Park Cres",
#   'physical_configuration': 'REGULAR',
#   'lat': 43.663376,
#   'lon': -79.392125,
#   'altitude': None,
#   'address': "Wellesley St W / Queen's Park Cres",
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9648',
#   'short_name': '647-643-9648',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7010',
#   'external_id': 'f8ab5fcc-e9c7-11ef-984e-124c66246c7d',
#   'name': 'King St W / Spadina Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.64514249449372,
#   'lon': -79.39510358283808,
#   'altitude': None,
#   'address': 'King St W / Spadina Ave',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-202-6537',
#   'short_name': '647-202-6537',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7013',
#   'external_id': 'f8ab675c-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Scott St / The Esplanade',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.64659663170443,
#   'lon': -79.37530913867988,
#   'altitude': 0.0,
#   'address': 'Scott St / The Esplanade',
#   'post_code': 'M5E 1Z4',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '416-666-6440',
#   'short_name': '416-666-6440',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7014',
#   'external_id': 'f8ab69cf-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Sherbourne St / Carlton St (Allan Gardens)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.663102,
#   'lon': -79.373181,
#   'altitude': None,
#   'address': 'Sherbourne St / Carlton St (Allan Gardens)',
#   'capacity': 17,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '416-710-6764',
#   'short_name': '416-710-6764',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7015',
#   'external_id': 'f8ab6c2a-e9c7-11ef-984e-124c66246c7d',
#   'name': 'King St W / Bay St (West Side)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.64852,
#   'lon': -79.380576,
#   'altitude': None,
#   'address': 'King St W / Bay St (West Side)',
#   'capacity': 39,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['Valet Stations', 'South', 'Financial District'],
#   'obcn': '416-671-7595',
#   'short_name': '416-671-7595',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7016',
#   'external_id': 'f8ab6eb0-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / Queens Quay W (Ferry Terminal)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.640978,
#   'lon': -79.376785,
#   'altitude': None,
#   'address': 'Bay St / Queens Quay W (Ferry Terminal)',
#   'post_code': 'M5J',
#   'capacity': 35,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['South', 'Watefront'],
#   'obcn': '647-271-1378',
#   'short_name': '647-271-1378',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7017',
#   'external_id': 'f8ab715f-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Widmer St / Adelaide St W - SMART',
#   'physical_configuration': 'SMARTMAPFRAME',
#   'lat': 43.647547634759206,
#   'lon': -79.39155200496292,
#   'altitude': 0.0,
#   'address': 'Widmer St / Adelaide St W',
#   'post_code': 'M5V 1J9',
#   'capacity': 12,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-631-9958',
#   'short_name': '647-631-9958',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7018',
#   'external_id': 'f8ab73f6-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bremner Blvd / Rees St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.641529,
#   'lon': -79.386741,
#   'altitude': None,
#   'address': 'Bremner Blvd / Rees St',
#   'cross_street': 'Bremner Blvd / Rees St',
#   'capacity': 48,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['South', 'Watefront'],
#   'obcn': '647-669-0947',
#   'short_name': '647-669-0947',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7019',
#   'external_id': 'f8ab7671-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Temperance St Station',
#   'physical_configuration': 'VAULT',
#   'lat': 43.650945,
#   'lon': -79.379498,
#   'altitude': None,
#   'address': 'Temperance St. Station',
#   'post_code': 'M5H 1Y6',
#   'capacity': 55,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['Valet Stations', 'South', 'Financial District'],
#   'obcn': '9 Temperance St .',
#   'short_name': '9 Temperance St .',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7020',
#   'external_id': 'f8ab796c-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Phoebe St / Spadina Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.650033,
#   'lon': -79.396555,
#   'altitude': None,
#   'address': 'Phoebe St / Spadina Ave',
#   'capacity': 33,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-621-5766',
#   'short_name': '647-621-5766',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7021',
#   'external_id': 'f8acb80a-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / Albert St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.653264,
#   'lon': -79.382458,
#   'altitude': None,
#   'address': 'Bay St / Albert St',
#   'capacity': 63,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-643-9652',
#   'short_name': '647-643-9652',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7023',
#   'external_id': 'f8ad026d-e9c7-11ef-984e-124c66246c7d',
#   'name': 'College St / Borden St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.6571,
#   'lon': -79.4056,
#   'altitude': None,
#   'address': 'College St / Borden St',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'College St - Harbord St'],
#   'obcn': '647-643-9629',
#   'short_name': '647-643-9629',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7024',
#   'external_id': 'f8ad04fa-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Dundonald St / Church St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.66663,
#   'lon': -79.38148,
#   'altitude': 0.0,
#   'address': 'Dundonald St / Church St',
#   'capacity': 38,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '647-631-9859',
#   'short_name': '647-631-9859',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7025',
#   'external_id': 'f8ad0779-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Ted Rogers Way / Bloor St E',
#   'physical_configuration': 'VAULT',
#   'lat': 43.671293,
#   'lon': -79.380471,
#   'altitude': None,
#   'address': 'Ted Rogers Way / Bloor St E',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '647-631-9970',
#   'short_name': '647-631-9970',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7026',
#   'external_id': 'f8ad0a28-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / St. Joseph St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.665527,
#   'lon': -79.387499,
#   'altitude': None,
#   'address': 'Bay St / St. Joseph St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '416-666-0783',
#   'short_name': '416-666-0783',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7027',
#   'external_id': 'f8ad0c95-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Beverley St / Dundas St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.652823,
#   'lon': -79.393388,
#   'altitude': None,
#   'address': 'Beverley  St / Dundas St W',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-621-6739',
#   'short_name': '647-621-6739',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7028',
#   'external_id': 'f8ad0ee6-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Gould St / Mutual St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6582,
#   'lon': -79.3768,
#   'altitude': None,
#   'address': 'Gould St / Mutual St',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '416-560-7261',
#   'short_name': '416-560-7261',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7029',
#   'external_id': 'f8ad113b-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / Bloor St W (East Side)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.66943,
#   'lon': -79.38915,
#   'altitude': None,
#   'address': '1199 Bay St',
#   'post_code': 'M6G1X2',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['North', 'Church Wellesley / Yorkville'],
#   'obcn': '647-669-3457',
#   'short_name': '647-669-3457',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7030',
#   'external_id': 'f8ad1392-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bay St / Wellesley St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.664088,
#   'lon': -79.387095,
#   'altitude': None,
#   'address': 'Bay St / Wellesley St W',
#   'capacity': 35,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9612',
#   'short_name': '647-643-9612',
#   'nearby_distance': 1609.34,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7031',
#   'external_id': 'f8ad15ed-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Jarvis St / Isabella St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.668991,
#   'lon': -79.379385,
#   'altitude': None,
#   'address': 'Jarvis St / Isabella St',
#   'capacity': 39,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '416-569-7503',
#   'short_name': '416-569-7503',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7032',
#   'external_id': 'f8ad1836-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Augusta Ave / Dundas St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.652473,
#   'lon': -79.401456,
#   'altitude': None,
#   'address': 'Augusta Ave / Dundas St W',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'College St - Harbord St'],
#   'obcn': '647-622-8139',
#   'short_name': '647-622-8139',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7033',
#   'external_id': 'f8ad1af4-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Union Station',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.645609,
#   'lon': -79.380386,
#   'altitude': 1.0,
#   'address': 'Union Station',
#   'post_code': 'M5J1E3',
#   'capacity': 43,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['Valet Stations', 'South', 'Financial District'],
#   'obcn': '647-620-1494',
#   'short_name': '647-620-1494',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7034',
#   'external_id': 'f8ad1d3d-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Church St / Bloor St E',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.671389,
#   'lon': -79.382919,
#   'altitude': None,
#   'address': 'Church St / Bloor St E',
#   'cross_street': '11',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['North', 'Church Wellesley / Yorkville'],
#   'obcn': '437-992-7029',
#   'short_name': '437-992-7029',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7035',
#   'external_id': 'f8ad1fd2-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Queen St W / Ossington Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.643975,
#   'lon': -79.419576,
#   'altitude': None,
#   'address': 'Queen St W / Ossington Ave',
#   'capacity': 43,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['West', 'Liberty Village - Queen West'],
#   'obcn': '416-371-6632',
#   'short_name': '416-371-6632',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7036',
#   'external_id': 'f8ad222f-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Trinity St /Front St E',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.651318,
#   'lon': -79.36023,
#   'altitude': None,
#   'address': 'Trinity St / Front St E',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Regent Park - Distillery'],
#   'obcn': '416-816-5603',
#   'short_name': '416-816-5603',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7037',
#   'external_id': 'f8af0ce1-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bathurst St / Dundas St W',
#   'physical_configuration': 'VAULT',
#   'lat': 43.65220761646196,
#   'lon': -79.4055689857289,
#   'altitude': None,
#   'address': 'Bathurst St / Dundas St W',
#   'post_code': 'M5T 2S3',
#   'capacity': 41,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'College St - Harbord St'],
#   'obcn': '647-621-8042',
#   'short_name': '647-621-8042',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7038',
#   'external_id': 'f8af1118-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Dundas St W / Yonge St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.656094,
#   'lon': -79.381484,
#   'altitude': None,
#   'address': 'Dundas St W / Yonge St',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-643-9714',
#   'short_name': '647-643-9714',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7039',
#   'external_id': 'f8af1407-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Simcoe St / Michael Sweet Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.652327224103,
#   'lon': -79.3882538196087,
#   'altitude': 0.0,
#   'address': 'Simcoe St / Michael Sweet Ave',
#   'post_code': 'M5T3M3',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-202-6089',
#   'short_name': '647-202-6089',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7040',
#   'external_id': 'f8af169a-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Euclid Ave / Bloor St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.664467,
#   'lon': -79.414783,
#   'altitude': None,
#   'address': 'Euclid Ave / Bloor St W',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['West', 'Bloor St W / Annex'],
#   'obcn': '416-565-9380',
#   'short_name': '416-565-9380',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7041',
#   'external_id': 'f8af196e-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Edward St / Yonge St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.656729,
#   'lon': -79.382736,
#   'altitude': None,
#   'address': 'Edward St / Yonge St',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-643-9697',
#   'short_name': '647-643-9697',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7042',
#   'external_id': 'f8af1c16-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Sherbourne St / Wellesley St E',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6673,
#   'lon': -79.374,
#   'altitude': None,
#   'address': 'Sherbourne St / Wellesley St E',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '416-804-0543',
#   'short_name': '416-804-0543',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7043',
#   'external_id': 'f8af1ede-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Queens Quay W / Lower Simcoe St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.63951,
#   'lon': -79.383717,
#   'altitude': None,
#   'address': 'Queens Quay W / Lower Simcoe St',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '647-204-1380',
#   'short_name': '647-204-1380',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7044',
#   'external_id': 'f8af2198-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Church St / Alexander St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.663722,
#   'lon': -79.380288,
#   'altitude': None,
#   'address': 'Church St / Alexander St',
#   'capacity': 35,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '647-618-1341',
#   'short_name': '647-618-1341',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7045',
#   'external_id': 'f8af257c-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Bond St / Queen St E',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.653236,
#   'lon': -79.376716,
#   'altitude': None,
#   'address': 'Bond St / Queen St E',
#   'capacity': 37,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-629-0639',
#   'short_name': '647-629-0639',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7046',
#   'external_id': 'f8af27f8-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Niagara St / Richmond St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.64534,
#   'lon': -79.409597,
#   'altitude': None,
#   'address': 'Niagara St / Richmond St W',
#   'capacity': 42,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['West', 'Liberty Village - Queen West'],
#   'obcn': '647-643-9655',
#   'short_name': '647-643-9655',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7047',
#   'external_id': 'f8af2a5b-e9c7-11ef-984e-124c66246c7d',
#   'name': 'University Ave / Gerrard St W (East Side)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.657763,
#   'lon': -79.389165,
#   'altitude': None,
#   'address': 'University Ave / Gerrard St W',
#   'capacity': 25,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'is_valet_station': False,
#   'groups': ['Valet Stations', 'South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9690',
#   'short_name': '647-643-9690',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7048',
#   'external_id': 'f8b05e12-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Front St W / Yonge St (Hockey Hall of Fame)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.646322912152456,
#   'lon': -79.37746467249836,
#   'altitude': None,
#   'address': 'Front St W / Yonge St (Hockey Hall of Fame)',
#   'capacity': 47,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-204-0984',
#   'short_name': '647-204-0984',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7049',
#   'external_id': 'f8b0623d-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Portland St / Queen St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.6476,
#   'lon': -79.4015,
#   'altitude': None,
#   'address': 'Queen St W / Portland St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-624-3144',
#   'short_name': '647-624-3144',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7050',
#   'external_id': 'f8b06500-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Richmond St E / Jarvis St Green P',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.652634,
#   'lon': -79.374222,
#   'altitude': None,
#   'address': 'Richmond St E / Jarvis St Green P',
#   'capacity': 16,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'South'],
#   'obcn': '416-602-5376',
#   'short_name': '416-602-5376',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7052',
#   'external_id': 'f8b069fc-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Wellington St W / Bay St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.647259,
#   'lon': -79.379878,
#   'altitude': None,
#   'address': 'Wellington St W / Bay St',
#   'capacity': 55,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '416-723-3438',
#   'short_name': '416-723-3438',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7053',
#   'external_id': 'f8b06c56-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Metro Hall Plaza',
#   'physical_configuration': 'VAULT',
#   'lat': 43.645859,
#   'lon': -79.38783,
#   'altitude': None,
#   'address': 'Metro Hall Plaza',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-201-7794',
#   'short_name': '647-201-7794',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7054',
#   'external_id': 'f8b06ebe-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Navy Wharf Crt / Bremner Blvd',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.640722,
#   'lon': -79.391051,
#   'altitude': None,
#   'address': 'Navy Wharf Ct. / Bremner Blvd.',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '416-662-2516',
#   'short_name': '416-662-2516',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7055',
#   'external_id': 'f8b07124-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Jarvis St / Carlton St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.66207,
#   'lon': -79.37617,
#   'altitude': None,
#   'address': 'Jarvis St / Carlton St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '416-722-3901',
#   'short_name': '416-722-3901',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7057',
#   'external_id': 'f8b075df-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Simcoe St / Wellington St W South',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6458569,
#   'lon': -79.3853654,
#   'altitude': None,
#   'address': 'Simcoe St / Wellington St 1',
#   'post_code': 'M6a1a1',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-641-2103',
#   'short_name': '647-641-2103',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7058',
#   'external_id': 'f8b07b6a-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Huron St / Harbord St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6637,
#   'lon': -79.400053,
#   'altitude': None,
#   'address': 'Huron/ Harbord St',
#   'capacity': 39,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Bloor St W / Annex', 'College St - Harbord St'],
#   'obcn': '647-643-9725',
#   'short_name': '647-643-9725',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7059',
#   'external_id': 'f8b07e08-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Front St W / Blue Jays Way',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.643473,
#   'lon': -79.390477,
#   'altitude': None,
#   'address': 'Front St W / Blue Jays Way',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '647-241-7299',
#   'short_name': '647-241-7299',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7061',
#   'external_id': 'f8b36909-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Dalton Rd / Bloor St W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.6662942,
#   'lon': -79.4066433,
#   'altitude': None,
#   'address': 'Dalton Rd / Bloor St W',
#   'post_code': 'M6G1A1',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['North', 'Bloor St W / Annex'],
#   'obcn': '647-643-9676',
#   'short_name': '647-643-9676',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7063',
#   'external_id': 'f8b370a6-e9c7-11ef-984e-124c66246c7d',
#   'name': "Queen's Park / Bloor St W",
#   'physical_configuration': 'REGULAR',
#   'lat': 43.668456,
#   'lon': -79.393899,
#   'altitude': None,
#   'address': "Queen's Park / Bloor St W",
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '647-632-5491',
#   'short_name': '647-632-5491',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7064',
#   'external_id': 'f8b37382-e9c7-11ef-984e-124c66246c7d',
#   'name': '51 Parliament St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.652169,
#   'lon': -79.362841,
#   'altitude': None,
#   'address': '51 Parliament St',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Regent Park - Distillery'],
#   'obcn': '647-241-9519',
#   'short_name': '647-241-9519',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7065',
#   'external_id': 'f8b37621-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Dundas St E / Parliament St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.659575,
#   'lon': -79.365769,
#   'altitude': None,
#   'address': 'Dundas St E / Parliament St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Regent Park - Distillery'],
#   'obcn': '416-568-2679',
#   'short_name': '416-568-2679',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7066',
#   'external_id': 'f8b37ce4-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Willcocks St / St. George St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.662085,
#   'lon': -79.397735,
#   'altitude': None,
#   'address': 'Willcocks St / St. George St',
#   'cross_street': 'Willcocks St / St.George St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9624',
#   'short_name': '647-643-9624',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7067',
#   'external_id': 'f8b37f77-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Yonge St / Lake Shore Blvd E',
#   'physical_configuration': 'VAULT',
#   'lat': 43.643795,
#   'lon': -79.375413,
#   'altitude': None,
#   'address': 'Yonge St / Harbour St',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': [],
#   'obcn': '647-643-9613',
#   'short_name': '647-643-9613',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7069',
#   'external_id': 'f8b387a8-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Queen St W / Spadina Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.649147,
#   'lon': -79.395504,
#   'altitude': None,
#   'address': 'Queen St W / Spadina Ave',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '647-622-8344',
#   'short_name': '647-622-8344',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7070',
#   'external_id': 'f8b54552-e9c7-11ef-984e-124c66246c7d',
#   'name': '25 York St – Union Station South',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.643667,
#   'lon': -79.380414,
#   'altitude': None,
#   'address': '25 York St – Union Station South',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '416-624-8596',
#   'short_name': '416-624-8596',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7071',
#   'external_id': 'f8b54cab-e9c7-11ef-984e-124c66246c7d',
#   'name': '161 Bleecker St (South of Wellesley)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.666233,
#   'lon': -79.373327,
#   'altitude': 0.0,
#   'address': '161 Bleecker St (South of Wellesley)',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Church Wellesley / Yorkville'],
#   'obcn': '647-643-9846',
#   'short_name': '647-643-9846',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7073',
#   'external_id': 'f8b55701-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Spadina Ave / Fort York Blvd',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.640114,
#   'lon': -79.393249,
#   'altitude': None,
#   'address': 'Spadina Ave / Fort York Blvd',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '416-627-9646',
#   'short_name': '416-627-9646',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7074',
#   'external_id': 'f8b55d98-e9c7-11ef-984e-124c66246c7d',
#   'name': 'King St E / Church St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.650204164723476,
#   'lon': -79.37335141779099,
#   'altitude': None,
#   'address': 'St James Park',
#   'post_code': 'M5C 1G6',
#   'capacity': 55,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '647-643-9718',
#   'short_name': '647-643-9718',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7075',
#   'external_id': 'f8b5635f-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Queens Quay W / Dan Leckie Way',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.636533,
#   'lon': -79.395854,
#   'altitude': None,
#   'address': 'Queens Quay W / Dan Leckie Way',
#   'capacity': 27,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'South', 'Watefront'],
#   'obcn': '416-669-9604',
#   'short_name': '416-669-9604',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7076',
#   'external_id': 'f8b56c10-e9c7-11ef-984e-124c66246c7d',
#   'name': 'York St / Queens Quay W',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.640132,
#   'lon': -79.380464,
#   'altitude': None,
#   'address': 'York St / Queens Quay W',
#   'capacity': 57,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '416-618-7456',
#   'short_name': '416-618-7456',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7077',
#   'external_id': 'f8b5703f-e9c7-11ef-984e-124c66246c7d',
#   'name': 'College Park South',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.65945682499,
#   'lon': -79.38236466864778,
#   'altitude': None,
#   'address': 'College Park South',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'U of T - Hospital Row'],
#   'obcn': '647-643-9694',
#   'short_name': '647-643-9694',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7078',
#   'external_id': 'f8b57276-e9c7-11ef-984e-124c66246c7d',
#   'name': 'College St / Major St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.6576,
#   'lon': -79.4032,
#   'altitude': None,
#   'address': 'College St / Major St',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'College St - Harbord St'],
#   'obcn': '647-643-9638',
#   'short_name': '647-643-9638',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7079',
#   'external_id': 'f8b574c7-e9c7-11ef-984e-124c66246c7d',
#   'name': 'McGill St / Church St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.660694,
#   'lon': -79.379052,
#   'altitude': None,
#   'address': 'McGill St / Church St',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '437-999-8524',
#   'short_name': '437-999-8524',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7084',
#   'external_id': 'f8b5802b-e9c7-11ef-984e-124c66246c7d',
#   'name': 'High Park - Grenadier Cafe',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.645599,
#   'lon': -79.4657123,
#   'altitude': None,
#   'address': 'High Park - Grenadier Cafe',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['West', 'Bloor St W - High Park'],
#   'obcn': '647-643-9563',
#   'short_name': '647-643-9563',
#   'nearby_distance': 1609.34,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7085',
#   'external_id': 'f8b582ac-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Westlake Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.687323,
#   'lon': -79.304848,
#   'altitude': None,
#   'address': 'Danforth Ave / Westlake Ave',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-201-8853',
#   'short_name': '647-201-8853',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7086',
#   'external_id': 'f8b58521-e9c7-11ef-984e-124c66246c7d',
#   'name': 'High Park - West Rd',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.651922,
#   'lon': -79.465693,
#   'altitude': None,
#   'address': 'High Park - West Rd',
#   'post_code': '1324',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['West', 'Bloor St W - High Park'],
#   'obcn': '647-641-7093',
#   'short_name': '647-641-7093',
#   'nearby_distance': 1609.34,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7087',
#   'external_id': 'f8b58770-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Aldridge Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.684758,
#   'lon': -79.316767,
#   'altitude': None,
#   'address': 'Danforth Ave / Aldridge Ave',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-641-9873',
#   'short_name': '647-641-9873',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7088',
#   'external_id': 'f8b589b8-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Coxwell Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.683378,
#   'lon': -79.322961,
#   'altitude': 0.0,
#   'address': 'Danforth Ave / Coxwell Ave',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-248-5891',
#   'short_name': '647-248-5891',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7089',
#   'external_id': 'f8b58be5-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Church St  / Wood St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.662712,
#   'lon': -79.379903,
#   'altitude': 102.08,
#   'address': 'Church St / Wood St',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '647-262-1148',
#   'short_name': '647-262-1148',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7090',
#   'external_id': 'f8b58e1d-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Lamb Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.681991,
#   'lon': -79.329455,
#   'altitude': None,
#   'address': 'Danforth Ave / Lamb Ave',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-641-6203',
#   'short_name': '647-641-6203',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7091',
#   'external_id': 'f8b59052-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Donlands Subway Station',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.681114,
#   'lon': -79.3373885,
#   'altitude': None,
#   'address': 'Donlands Station',
#   'post_code': 'M4J 1P3',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-669-1705',
#   'short_name': '647-669-1705',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7093',
#   'external_id': 'f8b594af-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Gough Ave',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.678401,
#   'lon': -79.346289,
#   'altitude': None,
#   'address': 'Danforth Ave / Gough Ave',
#   'capacity': 24,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-669-1671',
#   'short_name': '647-669-1671',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7094',
#   'external_id': 'f8b596fc-e9c7-11ef-984e-124c66246c7d',
#   'name': '14 Arundel Ave',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.6784834,
#   'lon': -79.3513564,
#   'altitude': None,
#   'address': '14 Arundel Ave',
#   'cross_street': 'Arundel Ave - Chester Subway station',
#   'post_code': 'M4K 3A2',
#   'capacity': 25,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'East', 'Danforth'],
#   'obcn': '14 Arundel Ave - EBS - @CP 87',
#   'short_name': '14 Arundel Ave - EBS - @CP 87',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7095',
#   'external_id': 'f8b59956-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Danforth Ave / Ellerbeck St',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.677076,
#   'lon': -79.35667,
#   'altitude': None,
#   'address': 'Danforth Ave / Ellerbeck St',
#   'capacity': 14,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Danforth'],
#   'obcn': '647-669-1678',
#   'short_name': '647-669-1678',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7096',
#   'external_id': 'f8b59b95-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Lower Don River Trail and Taylor Creek Trail',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.7027268,
#   'lon': -79.33368089999999,
#   'altitude': None,
#   'address': '425 Don Mills Rd',
#   'post_code': 'M4J',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Thorncliffe Park - Sunnybrook'],
#   'obcn': '647-669-3908',
#   'short_name': '647-669-3908',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7097',
#   'external_id': 'f8b59dda-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Riverdale Park North (Broadview Ave)',
#   'physical_configuration': 'REGULAR',
#   'lat': 43.671172,
#   'lon': -79.354704,
#   'altitude': None,
#   'address': 'Riverdale Park North (Broadview Ave)',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['East', 'Leslieville - Woodbine'],
#   'obcn': '647-643-9838',
#   'short_name': '647-643-9838',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7098',
#   'external_id': 'f8b5a018-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Riverdale Park South (Broadview Ave)',
#   'physical_configuration': 'VAULT',
#   'lat': 43.667819,
#   'lon': -79.35347,
#   'altitude': None,
#   'address': 'Riverdale Park South (Broadview Ave)',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East', 'Leslieville - Woodbine'],
#   'obcn': '450 Broadview Ave ',
#   'short_name': '450 Broadview Ave ',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '7099',
#   'external_id': 'f8b5a254-e9c7-11ef-984e-124c66246c7d',
#   'name': 'Mill St / Cherry St',
# ...
#   'altitude': 0.0,
#   'address': 'Lawrence East Station',
#   'cross_street': 'Lawrence Ave E / Kennedy Rd',
#   'post_code': 'M1P 5G5',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East',
#    'Scarborough - Rouge Hill',
#    'Wexford / Marydale',
#    'Bendale'],
#   'obcn': '134 Mike Myers Dr',
#   'short_name': '134 Mike Myers Dr',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8167',
#   'external_id': '581bd71d-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Woburn Ave / Avenue Rd',
#   'physical_configuration': 'VAULT',
#   'lat': 43.72545280998933,
#   'lon': -79.41648817539286,
#   'altitude': 0.0,
#   'address': 'Woburn Ave / Avenue Rd',
#   'cross_street': 'Woburn Ave / Avenue Rd',
#   'post_code': 'M5M 3X8',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['Thorncliffe Park - Sunnybrook', 'North York - Willowdale'],
#   'obcn': '1623 Avenue Rd',
#   'short_name': '1623 Avenue Rd',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8168',
#   'external_id': '581bd9f6-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Portland St / Front St W',
#   'physical_configuration': 'VAULT',
#   'lat': 43.641634085638955,
#   'lon': -79.3987894305286,
#   'altitude': 0.0,
#   'address': 'Portland St / Front St W',
#   'cross_street': 'Portland St / Front St W',
#   'post_code': 'M5V 1B8',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Fort York - Entertainment District'],
#   'obcn': '530 Front St W',
#   'short_name': '530 Front St W',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8169',
#   'external_id': '581bdcb7-da3e-11f0-b51f-1214620ec1db',
#   'name': 'William Cragg Dr / Jane St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.72254631047244,
#   'lon': -79.50861414468879,
#   'altitude': 0.0,
#   'address': 'William Cragg Dr / Jane St',
#   'cross_street': 'William Cragg Dr / Jane St',
#   'post_code': 'M3M 1A5',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'North York - York U', 'North York - Willowdale'],
#   'obcn': '2205 Jane St ',
#   'short_name': '2205 Jane St ',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8170',
#   'external_id': '581bdf69-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Munition St / Commissioners St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.64652927223706,
#   'lon': -79.35032977085585,
#   'altitude': 0.0,
#   'address': 'Munition St / Commissioners St',
#   'cross_street': 'Munition St / Commissioners St',
#   'post_code': 'M5A 3S1',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '30 Munition St ',
#   'short_name': '30 Munition St ',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8171',
#   'external_id': '581be20f-da3e-11f0-b51f-1214620ec1db',
#   'name': ' Grafton Ave / Roncesvalles Ave',
#   'physical_configuration': 'VAULT',
#   'lat': 43.639598669893616,
#   'lon': -79.44621279276677,
#   'altitude': 0.0,
#   'address': ' Grafton Ave / Roncesvalles',
#   'cross_street': ' Grafton Ave / Roncesvalles',
#   'post_code': 'M6R 3B2',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['West', 'Liberty Village - Queen West'],
#   'obcn': '27 Roncesvalles Ave',
#   'short_name': '27 Roncesvalles Ave',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8172',
#   'external_id': '581be4ba-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Silverthorn Ave / Pryor Ave',
#   'physical_configuration': 'VAULT',
#   'lat': 43.67485699930531,
#   'lon': -79.46019152027287,
#   'altitude': 0.0,
#   'address': 'Silverthorn Ave / Pryor Ave',
#   'cross_street': 'Silverthorn Ave / Pryor Ave',
#   'post_code': 'M6N 3J6',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'St Clair Ave W'],
#   'obcn': '27 Silverthorn Ave',
#   'short_name': '27 Silverthorn Ave',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8173',
#   'external_id': '581be766-da3e-11f0-b51f-1214620ec1db',
#   'name': 'St. Clair Ave W / Poplar Plains Rd',
#   'physical_configuration': 'VAULT',
#   'lat': 43.68600191952118,
#   'lon': -79.40395327728031,
#   'altitude': 0.0,
#   'address': 'St. Clair Ave W / Poplar Plains Rd',
#   'cross_street': 'St. Clair Ave W / Poplar Plains Rd',
#   'post_code': 'M4V 0A5',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'St Clair Ave W'],
#   'obcn': '223 St Clair Ave W',
#   'short_name': '223 St Clair Ave W',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8174',
#   'external_id': '581bea10-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Wellington St E / Church St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.64864454643048,
#   'lon': -79.37419421546784,
#   'altitude': 0.0,
#   'address': 'Wellington St E / Church St',
#   'cross_street': 'Wellington St E / Church St',
#   'post_code': 'M5E 1C7',
#   'capacity': 19,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '44 Wellington St E',
#   'short_name': '44 Wellington St E',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8175',
#   'external_id': '581becc4-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Simcoe St / Wellington St W (North) 3',
#   'physical_configuration': 'VAULT',
#   'lat': 43.646226683295296,
#   'lon': -79.38553477700628,
#   'altitude': 0.0,
#   'address': 'Simcoe St / Wellington St W (North / 3)',
#   'cross_street': 'Simcoe St / Wellington St W ',
#   'post_code': 'M5J 0C2',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Financial District'],
#   'obcn': '56 Simcoe St',
#   'short_name': '56 Simcoe St',
#   'nearby_distance': 5.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8176',
#   'external_id': '581bf232-da3e-11f0-b51f-1214620ec1db',
#   'name': '9 Willingdon Blvd',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.64834720075349,
#   'lon': -79.51003768899298,
#   'altitude': 0.0,
#   'address': '9 Willingdon Blvd',
#   'cross_street': 'Willingdon Blvd / Bloor St W',
#   'post_code': 'M8X 2H1',
#   'capacity': 39,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'West', 'Bloor St W / Annex'],
#   'obcn': '9 Willingdon Blvd',
#   'short_name': '9 Willingdon Blvd',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8177',
#   'external_id': '581bf50d-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Linkwood Ln / Spanbridge Rd',
#   'physical_configuration': 'VAULT',
#   'lat': 43.7125731080812,
#   'lon': -79.32449549150107,
#   'altitude': 0.0,
#   'address': 'Linkwood Ln / Spanbridge Rd',
#   'cross_street': 'Linkwood Ln / Spanbridge Rd',
#   'post_code': 'M3C',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'Thorncliffe Park - Sunnybrook'],
#   'obcn': '981 Linkwood Ln',
#   'short_name': '981 Linkwood Ln',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8178',
#   'external_id': '581bf7c3-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Agincourt GO Station',
#   'physical_configuration': 'VAULT',
#   'lat': 43.78605668943663,
#   'lon': -79.28503072723657,
#   'altitude': 0.0,
#   'address': 'Agincourt GO Station',
#   'post_code': 'M1S 1B5',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East', 'Scarborough North'],
#   'obcn': '29 Reidmount Ave',
#   'short_name': '29 Reidmount Ave',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8179',
#   'external_id': '581bfa5a-da3e-11f0-b51f-1214620ec1db',
#   'name': 'McCowan Rd / Brimorton Dr',
#   'physical_configuration': 'VAULT',
#   'lat': 43.765737540515055,
#   'lon': -79.24922926555814,
#   'altitude': 0.0,
#   'address': 'McCowan Rd / Brimorton Dr',
#   'cross_street': 'McCowan Rd / Brimorton Dr',
#   'post_code': 'M1H 2C2',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['East', 'Scarborough - Rouge Hill'],
#   'obcn': '151 Brimorton Dr',
#   'short_name': '151 Brimorton Dr',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8180',
#   'external_id': '581bfcc4-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Osler Playground (Argyle St)',
#   'physical_configuration': 'VAULT',
#   'lat': 43.64640117586531,
#   'lon': -79.42195180747304,
#   'altitude': 0.0,
#   'address': 'Osler Playground (Argyle St)',
#   'post_code': 'M6J 1N7',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['West', 'Liberty Village - Queen West'],
#   'obcn': '123 Argyle St',
#   'short_name': '123 Argyle St',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8181',
#   'external_id': '581c010d-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Cherry St / Commissioners St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.64483932280588,
#   'lon': -79.35330371862767,
#   'altitude': 0.0,
#   'address': 'Cherry St / Commissioners St',
#   'cross_street': 'Cherry St / Commissioners St',
#   'post_code': 'M5A 3L3',
#   'capacity': 31,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': 'Commissioners St - Ward 14',
#   'short_name': 'Commissioners St - Ward 14',
#   'nearby_distance': 400.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8182',
#   'external_id': '581c03df-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Biidaasige Park (11 Munition St)',
#   'physical_configuration': 'VAULT',
#   'lat': 43.64621864215001,
#   'lon': -79.3500485188435,
#   'altitude': 0.0,
#   'address': 'Biidaasige Park (11 Munition St)',
#   'post_code': 'M5A 1A8',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Watefront'],
#   'obcn': '11 Munition St',
#   'short_name': '11 Munition St',
#   'nearby_distance': 400.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8183',
#   'external_id': '581c0666-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Dufferin St / King St W ',
#   'physical_configuration': 'VAULT',
#   'lat': 43.6391706,
#   'lon': -79.4272676,
#   'altitude': 0.0,
#   'address': 'Dufferin St / King St W ',
#   'cross_street': 'Dufferin St / King St W ',
#   'post_code': 'M6K 1Z7',
#   'capacity': 23,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['West', 'Liberty Village - Queen West'],
#   'obcn': '283 Dufferin St ',
#   'short_name': '283 Dufferin St ',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8184',
#   'external_id': '581c0c1d-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Antibes Dr / Bathurst St',
#   'physical_configuration': 'VAULT',
#   'lat': 43.78133435761008,
#   'lon': -79.44592470500392,
#   'altitude': 0.0,
#   'address': 'Antibes Dr / Bathurst St',
#   'cross_street': 'Antibes Dr / Bathurst St',
#   'post_code': 'M2R',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'North York - York U', 'North York - Willowdale'],
#   'obcn': '145 Antibes Dr',
#   'short_name': '145 Antibes Dr',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8185',
#   'external_id': '581c0ef9-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Laird Crosstown Station',
#   'physical_configuration': 'VAULT',
#   'lat': 43.71362626097812,
#   'lon': -79.36373329276721,
#   'altitude': 0.0,
#   'address': 'Laird Crosstown Station',
#   'cross_street': 'Eglinton Ave E / Laird Dr',
#   'post_code': 'M4P 1A6',
#   'capacity': 11,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['North', 'Thorncliffe Park - Sunnybrook'],
#   'obcn': '827 Eglinton Ave E',
#   'short_name': '827 Eglinton Ave E',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8187',
#   'external_id': '581c1550-da3e-11f0-b51f-1214620ec1db',
#   'name': 'Glen Rd / Bloor St',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.67208795610631,
#   'lon': -79.37490138634823,
#   'altitude': 0.0,
#   'address': 'Glen Rd / Bloor St',
#   'cross_street': 'Glen Rd / Bloor St',
#   'post_code': 'M4X 1M5',
#   'capacity': 15,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'North'],
#   'obcn': '26 Glen Rd',
#   'short_name': '26 Glen Rd',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8188',
#   'external_id': '581c1820-da3e-11f0-b51f-1214620ec1db',
#   'name': '16 John St',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.70133600868564,
#   'lon': -79.51748388371117,
#   'altitude': 0.0,
#   'address': '16 John St',
#   'cross_street': 'John St / Weston Rd',
#   'post_code': 'M9N 0B2',
#   'capacity': 23,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'North', 'Eglinton Ave W'],
#   'obcn': '16 John St',
#   'short_name': '16 John St',
#   'nearby_distance': 1000.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8189',
#   'external_id': '581c1ae2-da3e-11f0-b51f-1214620ec1db',
#   'name': '25 St. Mary St ',
#   'physical_configuration': 'VAULT',
#   'lat': 43.66756931923832,
#   'lon': -79.38749409709389,
#   'altitude': 0.0,
#   'address': '25 St. Mary St ',
#   'cross_street': 'St. Mary St / Bay St',
#   'post_code': 'M4Y 1R2',
#   'capacity': 15,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'groups': ['South', 'Church Wellesley / Yorkville'],
#   'obcn': '25 St. Mary St ',
#   'short_name': '25 St. Mary St ',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  {'station_id': '8190',
#   'external_id': '581c1d9a-da3e-11f0-b51f-1214620ec1db',
#   'name': '1651 Queen St E',
#   'physical_configuration': 'VAULT',
#   'lat': 43.66669198937586,
#   'lon': -79.31437376868756,
#   'altitude': 0.0,
#   'address': '1651 Queen St E',
#   'cross_street': 'Queen St E / Eastern Ave',
#   'post_code': 'M4L 1G5',
#   'capacity': 27,
#   'is_charging_station': False,
#   'rental_methods': ['key', 'transitcard', 'phone'],
#   'is_valet_station': True,
#   'groups': ['South', 'Leslieville - Woodbine'],
#   'obcn': '1651 Queen St E',
#   'short_name': '1651 Queen St E',
#   'nearby_distance': 500.0,
#   '_ride_code_support': True,
#   'rental_uris': {},
#   '_valet_station_details': 'Valet to support the Arkells concert.'},
#  {'station_id': '8191',
#   'external_id': 'd5dcfc3f-b73a-459a-b7f1-6a07fd107e4e',
#   'name': '1141 Eastern Ave',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 43.665673582957965,
#   'lon': -79.31439299262264,
#   'altitude': 0.0,
#   'address': '1141 Eastern Ave',
#   'post_code': 'M4L 1G5',
#   'capacity': 23,
#   'is_charging_station': True,
#   'rental_methods': ['key', 'transitcard', 'creditcard', 'phone'],
#   'groups': ['E-Charging ', 'South'],
#   'obcn': '4165683876',
#   'short_name': '4165683876',
#   'nearby_distance': 250.0,
#   '_ride_code_support': True,
#   'rental_uris': {}},
#  ...]

# %%
import pandas as pd

df = pd.DataFrame(station_info)
df.head()
# Out:
#   station_id                           external_id  \
# 0       7000  f8aa7900-e9c7-11ef-984e-124c66246c7d
# 1       7001  f8aaeb6e-e9c7-11ef-984e-124c66246c7d
# 2       7002  f8aaef03-e9c7-11ef-984e-124c66246c7d
# 3       7003  f8ab20ac-e9c7-11ef-984e-124c66246c7d
# 4       7005  f8ab51f8-e9c7-11ef-984e-124c66246c7d
#
#                            name physical_configuration        lat        lon  \
# 0  Fort York  Blvd / Capreol Ct                REGULAR  43.639832 -79.395954
# 1     Wellesley Station Green P    ELECTRICBIKESTATION  43.664964 -79.383550
# 2    St. George St / Bloor St W                REGULAR  43.667131 -79.399555
# 3      Madison Ave / Bloor St W                REGULAR  43.667018 -79.402796
# 4           King St W / York St                  VAULT  43.648001 -79.383177
#
#    altitude                       address  capacity  is_charging_station  ...  \
# 0       NaN  Fort York  Blvd / Capreol Ct        47                False  ...
# 1       NaN             Yonge / Wellesley        23                 True  ...
# 2       NaN    St. George St / Bloor St W        19                False  ...
# 3       NaN      Madison Ave / Bloor St W        15                False  ...
# 4       0.0           King St W / York St        23                False  ...
#
#                                               groups          obcn  \
# 0        [South, Fort York - Entertainment District]  647-643-9607
# 1  [E-Charging , South, Church Wellesley / Yorkvi...  416-617-9576
# 2                     [South, U of T - Hospital Row]  647-643-9615
# 3                        [South, Bloor St W / Annex]  647-631-4587
# 4                        [South, Financial District]  647-643-9693
#
#      short_name nearby_distance  _ride_code_support  rental_uris post_code  \
# 0  647-643-9607           500.0                True           {}       NaN
# 1  416-617-9576           500.0                True           {}   M4Y 1G7
# 2  647-643-9615           500.0                True           {}       NaN
# 3  647-631-4587           500.0                True           {}       NaN
# 4  647-643-9693           500.0                True           {}       NaN
#
#   is_valet_station cross_street _valet_station_details
# 0              NaN          NaN                    NaN
# 1              NaN          NaN                    NaN
# 2              NaN          NaN                    NaN
# 3              NaN          NaN                    NaN
# 4              NaN          NaN                    NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   station_id              1046 non-null   object
#  1   external_id             1046 non-null   object
#  2   name                    1046 non-null   object
#  3   physical_configuration  1043 non-null   object
#  4   lat                     1046 non-null   float64
#  5   lon                     1046 non-null   float64
#  6   altitude                659 non-null    float64
#  7   address                 1045 non-null   object
#  8   capacity                1046 non-null   int64
#  9   is_charging_station     1046 non-null   bool
#  10  rental_methods          1043 non-null   object
#  11  groups                  1046 non-null   object
#  12  obcn                    1046 non-null   object
#  13  short_name              1046 non-null   object
#  14  nearby_distance         1046 non-null   float64
#  15  _ride_code_support      1046 non-null   bool
#  16  rental_uris             1046 non-null   object
#  17  post_code               755 non-null    object
#  18  is_valet_station        40 non-null     object
#  19  cross_street            380 non-null    object
#  20  _valet_station_details  3 non-null      object
# dtypes: bool(2), float64(4), int64(1), object(14)
# memory usage: 157.4+ KB

# %%
df["altitude"].unique()
# Out:
# array([   nan,   0.  ,   1.  , 102.08])

# %%
df["is_valet_station"].unique()
# Out:
# array([nan, False, True], dtype=object)

# %%
df["nearby_distance"].nunique()
# Out:
# 35

# %%
# drop altitude, groups, obc, rental_uris, _ride_code_support, cross_street, is_valet_station
cleaned = df.drop(columns=["altitude", "groups", "obcn", "rental_uris", "_ride_code_support", "cross_street", "is_valet_station"])
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   station_id              1046 non-null   object
#  1   external_id             1046 non-null   object
#  2   name                    1046 non-null   object
#  3   physical_configuration  1043 non-null   object
#  4   lat                     1046 non-null   float64
#  5   lon                     1046 non-null   float64
#  6   address                 1045 non-null   object
#  7   capacity                1046 non-null   int64
#  8   is_charging_station     1046 non-null   bool
#  9   rental_methods          1043 non-null   object
#  10  short_name              1046 non-null   object
#  11  nearby_distance         1046 non-null   float64
#  12  post_code               755 non-null    object
#  13  _valet_station_details  3 non-null      object
# dtypes: bool(1), float64(3), int64(1), object(9)
# memory usage: 107.4+ KB

# %%
cleaned["physical_configuration"].unique()
# Out:
# array(['REGULAR', 'ELECTRICBIKESTATION', 'VAULT', 'SMARTMAPFRAME', nan],
#       dtype=object)

# %%
cleaned[cleaned["physical_configuration"].isna()]
# Out:
#     station_id                           external_id  \
# 643       7794  f8c983a7-e9c7-11ef-984e-124c66246c7d
# 956       8147  581b99ab-da3e-11f0-b51f-1214620ec1db
# 957       8148  581b9c51-da3e-11f0-b51f-1214620ec1db
#
#                                       name physical_configuration        lat  \
# 643       York St / Harbour St (Love Park)                    NaN  43.641017
# 956      Widmer St / Adelaide St W (South)                    NaN  43.647300
# 957  Simcoe St / Wellington St W (North) 2                    NaN  43.646246
#
#            lon                            address  capacity  \
# 643 -79.380359   York St / Harbour St (Love Park)        16
# 956 -79.391313  Widmer St / Adelaide St W (South)         8
# 957 -79.385489       Simcoe St / Wellington St W          4
#
#      is_charging_station rental_methods                   short_name  \
# 643                False            NaN             96 Queens Quay W
# 956                False            NaN    Widmer St / Adelaide St W
# 957                False            NaN  Simcoe St / Wellington St W
#
#      nearby_distance post_code _valet_station_details
# 643            350.0       M5J                    NaN
# 956             20.0   M5V 2E8                    NaN
# 957             10.0   M5J 0C2                    NaN

# %%
cleaned[cleaned["address"].isna()]
# Out:
#     station_id                           external_id  \
# 689       7844  f8ca3017-e9c7-11ef-984e-124c66246c7d
#
#                               name physical_configuration        lat  \
# 689  Second St / Lake Shore Blvd W                  VAULT  43.601915
#
#            lon address  capacity  is_charging_station  \
# 689 -79.499419     NaN        15                False
#
#                 rental_methods                         short_name  \
# 689  [key, transitcard, phone]  Ward 3 - (2765 Lake Shore Blvd W)
#
#      nearby_distance post_code _valet_station_details
# 689            350.0   M8V 1H2                    NaN

# %%
cleaned[cleaned["name"] == cleaned["address"]].shape[0]
# Out:
# 653

# %%
#set all nulls to the station name
cleaned["address"].fillna(cleaned["name"], inplace=True)
# Out:
# /var/folders/kx/0yxjmr611n9b7fnqf983rl700000gn/T/ipykernel_34527/2573472537.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned["address"].fillna(cleaned["name"], inplace=True)

# %%
cleaned[cleaned["name"] == cleaned["address"]].shape[0]
# Out:
# 654

# %%
#replace missing config, rental methods, and postal code with "UNKNOWN"
df.columns[df.isnull().any()].tolist()
# Out:
# ['physical_configuration',
#  'altitude',
#  'address',
#  'rental_methods',
#  'post_code',
#  'is_valet_station',
#  'cross_street',
#  '_valet_station_details']

# %%
#cast dtype

# %%
station_status = client.fetch_data("station_status")
station_status["last_updated"]
# Out:
# 1781837538

# %%
status_df = pd.DataFrame(station_status["data"]["stations"])
status_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station_id                 1046 non-null   object
#  1   num_bikes_available        1046 non-null   int64
#  2   num_bikes_disabled         1046 non-null   int64
#  3   is_charging_station        1046 non-null   bool
#  4   status                     1046 non-null   object
#  5   traffic                    0 non-null      object
#  6   num_bikes_available_types  1046 non-null   object
#  7   num_docks_available        1046 non-null   int64
#  8   num_docks_disabled         1046 non-null   int64
#  9   last_reported              1046 non-null   int64
#  10  is_installed               1046 non-null   int64
#  11  is_renting                 1046 non-null   int64
#  12  is_returning               1046 non-null   int64
# dtypes: bool(1), int64(8), object(4)
# memory usage: 99.2+ KB

# %%
status_df.head()
# Out:
#   station_id  num_bikes_available  num_bikes_disabled  is_charging_station  \
# 0       7000                   42                   3                False
# 1       7001                    2                   4                 True
# 2       7002                    0                   2                False
# 3       7003                    1                   2                False
# 4       7005                    0                   0                False
#
#        status traffic       num_bikes_available_types  num_docks_available  \
# 0  IN_SERVICE    None  {'mechanical': 41, 'ebike': 1}                    1
# 1  IN_SERVICE    None   {'mechanical': 2, 'ebike': 0}                   17
# 2  IN_SERVICE    None   {'mechanical': 0, 'ebike': 0}                   16
# 3  IN_SERVICE    None   {'mechanical': 0, 'ebike': 1}                   12
# 4  IN_SERVICE    None   {'mechanical': 0, 'ebike': 0}                   23
#
#    num_docks_disabled  last_reported  is_installed  is_renting  is_returning
# 0                   1     1781837441             1           1             1
# 1                   0     1781837439             1           1             1
# 2                   1     1781837494             1           1             1
# 3                   0     1781837517             1           1             1
# 4                   0     1781837488             1           1             1
